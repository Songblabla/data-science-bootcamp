# %% [markdown]
# # Project

# %% [markdown]
# # Final Project - Analyzing Sales Data
#
# **Date**: 30 December 2021
#
# **Author**: Kasidis Satangmongkol (Toy DataRockie)
#
# **Course**: `Pandas Foundation`

# %%
# import data
import pandas as pd
df = pd.read_csv("sample-store.csv")

# %%
# preview top 5 rows
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Row ID</th>
#       <th>Order ID</th>
#       <th>Order Date</th>
#       <th>Ship Date</th>
#       <th>Ship Mode</th>
#       <th>Customer ID</th>
#       <th>Customer Name</th>
#       <th>Segment</th>
#       <th>Country/Region</th>
#       <th>City</th>
#       <th>...</th>
#       <th>Postal Code</th>
#       <th>Region</th>
#       <th>Product ID</th>
#       <th>Category</th>
#       <th>Sub-Category</th>
#       <th>Product Name</th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...

# %%
# shape of dataframe
df.shape
# Out:
# (9994, 21)

# %%
# see data frame information using .info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   object
#  3   Ship Date       9994 non-null   object
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Customer Name   9994 non-null   object
#  7   Segment         9994 non-null   object
#  8   Country/Region  9994 non-null   object
#  9   City            9994 non-null   object
#  10  State           9994 non-null   object
#  11  Postal Code     9983 non-null   float64
#  12  Region          9994 non-null   object
#  13  Product ID      9994 non-null   object
#  14  Category        9994 non-null   object
#  15  Sub-Category    9994 non-null   object
#  16  Product Name    9994 non-null   object
# ...

# %% [markdown]
# We can use `pd.to_datetime()` function to convert columns 'Order Date' and 'Ship Date' to datetime.

# %%
# example of pd.to_datetime() function
pd.to_datetime(df['Order Date'], format='%m/%d/%Y')
# Out:
# <pre>0      2019-11-08
# 1      2019-11-08
# 2      2019-06-12
# 3      2018-10-11
# 4      2018-10-11
#           ...
# 9989   2017-01-21
# 9990   2020-02-26
# 9991   2020-02-26
# 9992   2020-02-26
# 9993   2020-05-04
# Name: Order Date, Length: 9994, dtype: datetime64[ns]</pre>

# %%
# TODO - convert order date and ship date to datetime in the original dataframe
df['Order Date'] = pd.to_datetime(df['Order Date'], format='%m/%d/%Y')

# %%
df['Ship Date'] = pd.to_datetime(df['Ship Date'], format='%m/%d/%Y')

# %%
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Row ID</th>
#       <th>Order ID</th>
#       <th>Order Date</th>
#       <th>Ship Date</th>
#       <th>Ship Mode</th>
#       <th>Customer ID</th>
#       <th>Customer Name</th>
#       <th>Segment</th>
#       <th>Country/Region</th>
#       <th>City</th>
#       <th>...</th>
#       <th>Postal Code</th>
#       <th>Region</th>
#       <th>Product ID</th>
#       <th>Category</th>
#       <th>Sub-Category</th>
#       <th>Product Name</th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...

# %%
# TODO - count nan in postal code column
df['Postal Code'].isna().sum()
# Out:
# 11

# %%
# TODO - filter rows with missing values
df[df.isna()]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Row ID</th>
#       <th>Order ID</th>
#       <th>Order Date</th>
#       <th>Ship Date</th>
#       <th>Ship Mode</th>
#       <th>Customer ID</th>
#       <th>Customer Name</th>
#       <th>Segment</th>
#       <th>Country/Region</th>
#       <th>City</th>
#       <th>...</th>
#       <th>Postal Code</th>
#       <th>Region</th>
#       <th>Product ID</th>
#       <th>Category</th>
#       <th>Sub-Category</th>
#       <th>Product Name</th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...

# %% [markdown]
# ## Data Analysis Part
#
# Answer 10 below questions to get credit from this course. Write `pandas` code to find answers.

# %%
# TODO 01 - how many columns, rows in this dataset
df.shape
# Out:
# (9994, 21)

# %%
# TODO 02 - is there any missing values?, if there is, which colunm? how many nan values?
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      5 non-null      datetime64[ns]
#  3   Ship Date       5 non-null      datetime64[ns]
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Customer Name   9994 non-null   object
#  7   Segment         9994 non-null   object
#  8   Country/Region  9994 non-null   object
#  9   City            9994 non-null   object
#  10  State           9994 non-null   object
#  11  Postal Code     9983 non-null   float64
#  12  Region          9994 non-null   object
#  13  Product ID      9994 non-null   object
#  14  Category        9994 non-null   object
#  15  Sub-Category    9994 non-null   object
# ...

# %%
# TODO 03 - your friend ask for `California` data, filter it and export csv for him
df[df['State']=='California']
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Row ID</th>
#       <th>Order ID</th>
#       <th>Order Date</th>
#       <th>Ship Date</th>
#       <th>Ship Mode</th>
#       <th>Customer ID</th>
#       <th>Customer Name</th>
#       <th>Segment</th>
#       <th>Country/Region</th>
#       <th>City</th>
#       <th>...</th>
#       <th>Postal Code</th>
#       <th>Region</th>
#       <th>Product ID</th>
#       <th>Category</th>
#       <th>Sub-Category</th>
#       <th>Product Name</th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
# ...

# %%
# TODO 04 - your friend ask for all order data in `California` and `Texas` in 2017 (look at Order Date),  him csv file
df[((df['State']=='California') | (df['State'] == 'Texas')) & (df['Order Date'].dt.year == 2017)]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Row ID</th>
#       <th>Order ID</th>
#       <th>Order Date</th>
#       <th>Ship Date</th>
#       <th>Ship Mode</th>
#       <th>Customer ID</th>
#       <th>Customer Name</th>
#       <th>Segment</th>
#       <th>Country/Region</th>
#       <th>City</th>
#       <th>...</th>
#       <th>Postal Code</th>
#       <th>Region</th>
#       <th>Product ID</th>
#       <th>Category</th>
#       <th>Sub-Category</th>
#       <th>Product Name</th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>5</th>
# ...

# %%
# TODO 05 - how much total sales, average sales, and standard deviation of sales your company make in 2017
total_sales = df['Sales'][df['Order Date'].dt.year == 2017].sum()
average_sales = df['Sales'][df['Order Date'].dt.year == 2017].mean()
sd_sales = df['Sales'][df['Order Date'].dt.year == 2017].std()

print(total_sales)
print(average_sales)
print(sd_sales)
# Out:
# 484247.4981
# 242.97415860511794
# 754.0533572593683

# %%
# TODO 06 - which Segment has the highest profit in 2018

highest_profit_segment = df[ df['Order Date'].dt.year == 2018 ].groupby('Segment')['Profit'].sum()
highest_profit_segment.head(1)
# Out:
# <pre>Segment
# Consumer    28460.1665
# Name: Profit, dtype: float64</pre>

# %%
# TODO 07 - which top 5 States have the least total sales between 15 April 2019 - 31 December 2019
least_sales_segment = df[ (df['Order Date'] > '2019-04-15') & (df['Order Date'] < '2019-12-31' )].groupby('State')['Sales'].sum().reset_index().sort_values('Sales').head()
least_sales_segment
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>State</th>
#       <th>Sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>26</th>
#       <td>New Hampshire</td>
#       <td>49.05</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>New Mexico</td>
#       <td>64.08</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>District of Columbia</td>
#       <td>117.07</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Louisiana</td>
#       <td>249.80</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>South Carolina</td>
#       <td>502.48</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# TODO 08 - what is the proportion of total sales (%) in West + Central in 2019 e.g. 25% 
sales_total = df['Sales'].sum()
sales_region = df[(df['Order Date'].dt.year == 2019)].query(" Region == 'West' | Region == 'Central' ")
sales_central_west = sales_region['Sales'].sum()
proportion =  sales_central_west / sales_total
print(proportion * 100)
# Out:
# 14.579027819807749

# %%
# TODO 09 - find top 10 popular products in terms of number of orders vs. total sales during 2019-2020
df_year = df[ (df['Order Date'] > '2018-12-31') & (df['Order Date'] < '2021-01-01' )]
top10_product_order = df_year['Product Name'].value_counts().head(10)
top10_sales_order = df_year.groupby('Product Name')['Sales'].agg(['sum']).sort_values('sum',ascending = False).head(10)
top10_product_order
# Out:
# <pre>Easy-staple paper                                  27
# Staples                                            24
# Staple envelope                                    22
# Staples in misc. colors                            13
# Chromcraft Round Conference Tables                 12
# Storex Dura Pro Binders                            12
# Staple remover                                     12
# Global Wood Trimmed Manager's Task Chair, Khaki    11
# Avery Non-Stick Binders                            11
# Sterilite Officeware Hinged File Box               10
# Name: Product Name, dtype: int64</pre>

# %%
top10_sales_order.columns = {'Total Sales of this product'}
top10_sales_order
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Total Sales of this product</th>
#     </tr>
#     <tr>
#       <th>Product Name</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Canon imageCLASS 2200 Advanced Copier</th>
#       <td>61599.824</td>
#     </tr>
#     <tr>
#       <th>Hewlett Packard LaserJet 3310 Copier</th>
#       <td>16079.732</td>
#     </tr>
#     <tr>
#       <th>3D Systems Cube Printer, 2nd Generation, Magenta</th>
#       <td>14299.890</td>
#     </tr>
#     <tr>
#       <th>GBC Ibimaster 500 Manual ProClick Binding System</th>
#       <td>13621.542</td>
#     </tr>
#     <tr>
# ...

# %%
# TODO 10 - plot at least 2 plots, any plot you think interesting :)

#count number of product by segment
df['Segment'].value_counts().plot(kind='bar', color=['salmon','orange', 'gold']);

# %%
#wwhich state has the most sales
df[['State','Sales']].plot(x='State',y='Sales',kind='scatter', color=['salmon'],figsize = (50,100));
